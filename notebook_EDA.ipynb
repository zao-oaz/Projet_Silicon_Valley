# %% [markdown]
# # Exploratory data analysis

# %%
# Imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import l’ensemble des données dans DataFrame

# %%
immobilier_df = pd.read_csv("C:/Users/zaome/Documents/Arthuro/Projet_agent_immo/train_data.csv")
immobilier_df
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %% [markdown]
# Suppression de la première colonne "Unnamed : 0"

# %%
immobilier_df = immobilier_df.drop(columns=["Unnamed: 0"], axis=1)
immobilier_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.90     39.59                20.0       1465.0           278.0
# 16508    -122.25     38.11                49.0       2365.0           504.0
# 16509    -121.22     38.92                19.0       2531.0           461.0
# 16510    -118.14     34.16                39.0       2776.0           840.0
# 16511    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %%
immobilier_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16512 entries, 0 to 16511
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16336 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   median_house_value  16512 non-null  float64
#  9   ocean_proximity     16512 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# Nombre de cellules nulles (non renseignées) par colonnes

# %%
immobilier_df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        176
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
immobilier_df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     7312
# INLAND        5235
# NEAR OCEAN    2140
# NEAR BAY      1821
# ISLAND           4
# Name: ocean_proximity, dtype: int64
